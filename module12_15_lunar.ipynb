# %% [markdown]
# <a href="https://colab.research.google.com/github/minibrixie/module12-15_lunar/blob/main/module12_15_lunar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
filename = '/content/drive/MyDrive/Lunar_Activity/movies_metadata.csv'
df = pd.read_csv(filename)
# Out:
# <ipython-input-3-dbaface67af6>:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename)

# %%
df.head(10)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5  False                                                NaN  60000000
# 6  False                                                NaN  58000000
# 7  False                                                NaN         0
# 8  False                                                NaN  35000000
# 9  False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# ...

# %%
df.tail(10)
# Out:
#        adult belongs_to_collection budget  \
# 45456  False                   NaN      0
# 45457  False                   NaN      0
# 45458  False                   NaN      0
# 45459  False                   NaN      0
# 45460  False                   NaN      0
# 45461  False                   NaN      0
# 45462  False                   NaN      0
# 45463  False                   NaN      0
# 45464  False                   NaN      0
# 45465  False                   NaN      0
#
#                                                   genres  \
# 45456  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...
# 45457  [{'id': 9648, 'name': 'Mystery'}, {'id': 27, '...
# 45458                     [{'id': 27, 'name': 'Horror'}]
# 45459           [{'id': 878, 'name': 'Science Fiction'}]
# 45460  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# ...

# %%
df[['adult', 'budget']].head()
# Out:
#    adult    budget
# 0  False  30000000
# 1  False  65000000
# 2  False         0
# 3  False  16000000
# 4  False         0

# %%
df[['status', 'title']].tail()
# Out:
#          status                title
# 45461  Released               Subdue
# 45462  Released  Century of Birthing
# 45463  Released             Betrayal
# 45464  Released     Satan Triumphant
# 45465  Released             Queerama

# %%
df['title'].head()
# Out:
# 0                      Toy Story
# 1                        Jumanji
# 2               Grumpier Old Men
# 3              Waiting to Exhale
# 4    Father of the Bride Part II
# Name: title, dtype: object

# %%
type(df['original_title'].head())
# Out:
# pandas.core.series.Series

# %%
df['revenue', 'runtime']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('revenue', 'runtime')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df['revenue']
# Out:
# 0        373554033.0
# 1        262797249.0
# 2                0.0
# 3         81452156.0
# 4         76578911.0
#             ...
# 45461            0.0
# 45462            0.0
# 45463            0.0
# 45464            0.0
# 45465            0.0
# Name: revenue, Length: 45466, dtype: float64

# %%
df['title'][0:10]
# Out:
# 0                      Toy Story
# 1                        Jumanji
# 2               Grumpier Old Men
# 3              Waiting to Exhale
# 4    Father of the Bride Part II
# 5                           Heat
# 6                        Sabrina
# 7                   Tom and Huck
# 8                   Sudden Death
# 9                      GoldenEye
# Name: title, dtype: object

# %%
df.title.head()
# Out:
# 0                      Toy Story
# 1                        Jumanji
# 2               Grumpier Old Men
# 3              Waiting to Exhale
# 4    Father of the Bride Part II
# Name: title, dtype: object

# %%
df.loc[:, ['title']].head()
# Out:
#                          title
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II

# %%
df.loc[:, 'title'].head()
# Out:
# 0                      Toy Story
# 1                        Jumanji
# 2               Grumpier Old Men
# 3              Waiting to Exhale
# 4    Father of the Bride Part II
# Name: title, dtype: object

# %%
df['id'].value_counts()
# Out:
# 141971    3
# 168538    2
# 25541     2
# 15028     2
# 11115     2
#          ..
# 72272     1
# 1549      1
# 10171     1
# 38996     1
# 461257    1
# Name: id, Length: 45436, dtype: int64

# %%
mortgage_filter = df['original_title']=='Toy Story'
mortgage_filter.head()
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# Name: original_title, dtype: bool

# %%
df[mortgage_filter].head()
# Out:
# <ipython-input-90-dc439875436e>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[mortgage_filter].head()
# Empty DataFrame
# Columns: [belongs_to_collection, budget, genres, homepage, id, imdb_id, original_language, original_title, overview, ..., release_date, runtime, spoken_languages, status, tagline, title, video, vote_average, vote_count, , ]
# Index: []
#
# [0 rows x 21 columns]

# %%
df['original_title'].value_counts()
# Out:
# Hamlet                 8
# Alice in Wonderland    8
# Les Misérables         7
# Cinderella             7
# Macbeth                7
#                       ..
# 거미숲                    1
# What Goes Up           1
# 12th & Delaware        1
# Wonder Bar             1
# Queerama               1
# Name: original_title, Length: 43373, dtype: int64

# %%
df_filter=df['budget']=='16000000'
df_filter.head()
# Out:
# Series([], Name: budget, dtype: bool)

# %%
df[df_filter].head()
# Out:
# Empty DataFrame
# Columns: [adult, belongs_to_collection, budget, genres, homepage, id, imdb_id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, video, vote_average, vote_count]
# Index: []
#
# [0 rows x 24 columns]

# %%
df['adult'].value_counts()
# Out:
# Series([], Name: adult, dtype: int64)

# %%
df['adult']=='true'
# Out:
# Series([], Name: adult, dtype: bool)

# %%
budget_filter = df['adult']=='False'
df = df.loc[df_filter, :]
df['adult'].value_counts(dropna = False)
# Out:
# Series([], Name: adult, dtype: int64)

# %%
df=df.loc[df_filter & budget_filter, :]
df
# Out:
# Empty DataFrame
# Columns: [adult, belongs_to_collection, budget, genres, homepage, id, imdb_id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, video, vote_average, vote_count]
# Index: []
#
# [0 rows x 24 columns]

# %%
df = df.loc[mortgage_filter, :]
df['original_title'].value_counts()
# Out:
# Toy Story    1
# Name: original_title, dtype: int64

# %%
df['revenue'].value_counts()
# Out:
# 373554033.0    1
# Name: revenue, dtype: int64

# %%
df['revenue']==0.03
# Out:
# 0    False
# Name: revenue, dtype: bool

# %%
budget_filter = df['budget']==0.03
df = df.loc[budget_filter, :]
df['budget'].value_counts(dropna = False)
# Out:
# Series([], Name: budget, dtype: int64)

# %%
df = df.loc[mortgage_filter & interest_filter, :]
df
# Out:
# Empty DataFrame
# Columns: [belongs_to_collection, budget, genres, homepage, id, imdb_id, original_language, original_title, overview, ..., release_date, runtime, spoken_languages, status, tagline, title, video, vote_average, vote_count, , ]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.original_title
# Out:
# Series([], Name: original_title, dtype: object)

# %%
df = df.rename(columns={'adult': 'Adult',
'budget': 'Budget',
'genres': 'Genres'})
df.head()
# Out:
# Empty DataFrame
# Columns: [Adult, belongs_to_collection, Budget, Genres, homepage, id, imdb_id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, Revenue, runtime, spoken_languages, status, tagline, Title, video, vote_average, vote_count]
# Index: []
#
# [0 rows x 24 columns]

# %%
df = df.rename(columns={'belongs_to_collection': 'belongs_to_collection',
'homepage': 'homepage',
'id': 'id'})

df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
df.columns =['adult',	'belongs_to_collection',	'budget'	,'genres',	'homepage',	'id',	'imdb_id',	'original_language',	'original_title',	'overview',	'...',	'release_date',	'revenue',	'runtime'	,'spoken_languages',	'status',	'tagline',	'title',	'video',	'vote_average',	'vote_count','','']
df.head()
# Out:
#                                                adult belongs_to_collection  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...              30000000
# 1                                                NaN              65000000
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...                     0
# 3                                                NaN              16000000
# 4  {'id': 96871, 'name': 'Father of the Bride Col...                     0
#
#                                               budget  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                  genres homepage         id imdb_id  \
# 0  http://toystory.disney.com/toy-story      862  tt0114709      en
# ...

# %%
df = df.drop(columns=['adult'])
df.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                NaN  65000000
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                NaN  16000000
# 4  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# ...

# %%
del df['adult']
df.head()
# Out:
#   belongs_to_collection                                             budget  \
# 0              30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1              65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2                     0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3              16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     0                     [{'id': 35, 'name': 'Comedy'}]
#
#                                  genres homepage         id imdb_id  \
# 0  http://toystory.disney.com/toy-story      862  tt0114709      en
# 1                                   NaN     8844  tt0113497      en
# 2                                   NaN    15602  tt0113228      en
# 3                                   NaN    31357  tt0114885      en
# 4                                   NaN    11862  tt0113041      en
#
#              original_language  \
# 0                    Toy Story
# 1                      Jumanji
# ...

# %%
df.isna()
# Out:
#        belongs_to_collection  budget  genres  homepage     id  imdb_id  \
# 0                      False   False   False     False  False    False
# 1                      False   False    True     False  False    False
# 2                      False   False    True     False  False    False
# 3                      False   False    True     False  False    False
# 4                      False   False    True     False  False    False
# ...                      ...     ...     ...       ...    ...      ...
# 45461                  False   False   False     False  False    False
# 45462                  False   False    True     False  False    False
# 45463                  False   False    True     False  False    False
# 45464                  False   False    True     False  False    False
# 45465                  False   False    True     False  False    False
#
#        original_language  original_title  overview    ...  ...  runtime  \
# ...

# %%
df.isna().sum()
# Out:
# belongs_to_collection        0
# budget                       0
# genres                   37684
# homepage                     0
# id                          17
# imdb_id                     11
# original_language            0
# original_title             954
# overview                     5
# ...                        386
# release_date                 3
# revenue                      3
# runtime                     87
# spoken_languages             6
# status                     263
# tagline                      6
# title                       87
# video                    25054
# vote_average                 6
# vote_count                   6
#                              6
#                              6
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.dropna(subset=['title'], inplace=True)
df.isna().sum()
# Out:
# belongs_to_collection    0
# budget                   0
# genres                   0
# homepage                 0
# id                       0
# imdb_id                  0
# original_language        0
# original_title           0
# overview                 0
# ...                      0
# release_date             0
# revenue                  0
# runtime                  0
# spoken_languages         0
# status                   0
# tagline                  0
# title                    0
# video                    0
# vote_average             0
# vote_count               0
#                          0
#                          0
# dtype: int64

# %%
df.drop(columns='revenue', inplace=True)
df.isna().sum()
# Out:
# belongs_to_collection    0
# budget                   0
# genres                   0
# homepage                 0
# id                       0
# imdb_id                  0
# original_language        0
# original_title           0
# overview                 0
# ...                      0
# release_date             0
# runtime                  0
# spoken_languages         0
# status                   0
# tagline                  0
# title                    0
# video                    0
# vote_average             0
# vote_count               0
#                          0
#                          0
# dtype: int64

# %%
df.dropna(axis=1, inplace=True)

# %%
df.dropna(axis=1, thresh=.45, inplace=True)

# %%
df['title'].fillna('genre', inplace=True)

# %%
median_age = df['status'].median()
df['status'].fillna(median_age, inplace=True)
df.isna().sum()
# Out:
# belongs_to_collection    0
# budget                   0
# genres                   0
# homepage                 0
# id                       0
# imdb_id                  0
# original_language        0
# original_title           0
# overview                 0
# ...                      0
# release_date             0
# runtime                  0
# spoken_languages         0
# status                   0
# tagline                  0
# title                    0
# video                    0
# vote_average             0
# vote_count               0
#                          0
#                          0
# dtype: int64

# %%
most_common_title = df['title'].mode()
df['title'].fillna(most_common_title, inplace=True)

# %%
import pandas as pd
dp_colm= pd.read_csv('/content/drive/MyDrive/Lunar_Activity/movies_metadata.csv')
usecols=['imdb_id','genres', 'homepage','id','oiginal_title', 'overview'],
index_col=('imdb_id')
# Out:
# <ipython-input-25-8588fd466bcb>:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   dp_colm= pd.read_csv('/content/drive/MyDrive/Lunar_Activity/movies_metadata.csv')

# %%
dp_colm.head(5)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...
